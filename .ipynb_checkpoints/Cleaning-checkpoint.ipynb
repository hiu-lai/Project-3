# %%
#Import dependencies
import csv
import os
import os, fnmatch
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import date

# %%
for root, dirs, files in os.walk("resources", topdown=False):
    total_hab_files = []
    volume_projection_files = []
    for name in files:
        if os.path.join(name).startswith("Volume"):
            volume_projection_files.append(os.path.join(root, name))
        elif os.path.join(name).rfind("total"):
            total_hab_files.append(os.path.join(root, name))

# %%
number_of_files = len(total_hab_files)
number_of_files
# Out:
# 3

# %%
for i in range(number_of_files):
    file = total_hab_files[i]
    i = i + 1
    variable_name = f"total_{i}"
#     print(variable_name)
    globals()[variable_name] =  pd.read_csv(file)

# %%
if number_of_files == 3:
    total_temp = pd.concat([total_1, total_2])
    total = pd.concat([total_temp, total_3])
elif numfile == 2: 
    total = pd.concat([total_1, total_2])
else:
    total == total_1

# %%
total
# Out:
#        Geography Timeframe Current Year Week Ending          Type  \
# 0         Albany    Weekly      2020-01-06 00:00:00  Conventional
# 1         Albany    Weekly      2020-01-12 00:00:00  Conventional
# 2         Albany    Weekly      2020-01-19 00:00:00  Conventional
# 3         Albany    Weekly      2020-01-26 00:00:00  Conventional
# 4         Albany    Weekly      2020-02-02 00:00:00  Conventional
# ...          ...       ...                      ...           ...
# 1883        West    Weekly      2022-03-27 00:00:00       Organic
# 1884  Total U.S.    Weekly      2022-04-17 00:00:00       Organic
# 1885  Total U.S.    Weekly      2022-04-10 00:00:00       Organic
# 1886  Total U.S.    Weekly      2022-04-03 00:00:00       Organic
# 1887  Total U.S.    Weekly      2022-03-27 00:00:00       Organic
#
#       ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 0             1.155100                  161726.12     3737.00   140642.19
# 1             1.227609                  116738.30     3649.24    90717.11
# 2             1.088107                  138162.91     5057.86   108635.20
# 3             1.160866                  106202.76     4124.56    72571.73
# 4             1.251057                  186210.93     4933.07   156256.79
# ...                ...                        ...         ...         ...
# 1883          2.132444                  279969.07    16833.47    19138.13
# 1884          1.774314                 2073388.73    98894.63    93306.07
# 1885          1.734692                 2135495.11    84439.07   107442.51
# 1886          1.701004                 2180929.28    73724.50   107346.93
# 1887          1.712727                 2062180.86    73187.08    90293.07
#
#       4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# 0         184.16           10996.65              0.0              0.0
# 1         203.78           16359.88              0.0              0.0
# 2         306.59           15879.12              0.0              0.0
# 3         270.72           21273.86              0.0              0.0
# 4         215.29           17313.74              0.0              0.0
# ...          ...                ...              ...              ...
# 1883        0.00           89663.57              NaN              NaN
# 1884      412.89         1366905.16              NaN              NaN
# 1885      315.94         1417980.89              NaN              NaN
# 1886      306.77         1495281.89              NaN              NaN
# 1887      308.58         1410866.15              NaN              NaN
#
#       X-LrgBagged Units  Bulk GTIN
# 0                   0.0    6166.13
# 1                   0.0    5808.29
# 2                   0.0    8284.13
# 3                   0.0    7961.90
# 4                   0.0    7492.04
# ...                 ...        ...
# 1883                NaN  154333.89
# 1884                NaN  513869.98
# 1885                NaN  525316.71
# 1886                NaN  504269.19
# 1887                NaN  487525.98
#
# [13688 rows x 14 columns]

# %%
#Read in file
# file_df = pd.read_csv("resources/2020-plu-total-hab-data.csv", encoding = "UTF-8")

# file_df.head()

# %%
total.columns.tolist()
# Out:
# ['Geography',
#  'Timeframe',
#  'Current Year Week Ending',
#  'Type',
#  'ASP Current Year',
#  'Total Bulk and Bags Units',
#  '4046 Units',
#  '4225 Units',
#  '4770 Units',
#  'TotalBagged Units',
#  'SmlBagged Units',
#  'LrgBagged Units',
#  'X-LrgBagged Units',
#  'Bulk GTIN']

# %%
dropna_df = total.dropna(subset=['Geography',
 'Timeframe',
 'Current Year Week Ending',
 'Type',
 'ASP Current Year',
 'Total Bulk and Bags Units',
 '4046 Units',
 '4225 Units',
 '4770 Units',
 'TotalBagged Units',
 'SmlBagged Units',
 'LrgBagged Units',
 'X-LrgBagged Units',
 'Bulk GTIN'])
dropna_df.head()
# Out:
#   Geography Timeframe Current Year Week Ending          Type  \
# 0    Albany    Weekly      2020-01-06 00:00:00  Conventional
# 1    Albany    Weekly      2020-01-12 00:00:00  Conventional
# 2    Albany    Weekly      2020-01-19 00:00:00  Conventional
# 3    Albany    Weekly      2020-01-26 00:00:00  Conventional
# 4    Albany    Weekly      2020-02-02 00:00:00  Conventional
#
#    ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 0          1.155100                  161726.12     3737.00   140642.19
# 1          1.227609                  116738.30     3649.24    90717.11
# 2          1.088107                  138162.91     5057.86   108635.20
# 3          1.160866                  106202.76     4124.56    72571.73
# 4          1.251057                  186210.93     4933.07   156256.79
#
#    4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# 0      184.16           10996.65              0.0              0.0
# 1      203.78           16359.88              0.0              0.0
# 2      306.59           15879.12              0.0              0.0
# 3      270.72           21273.86              0.0              0.0
# 4      215.29           17313.74              0.0              0.0
#
#    X-LrgBagged Units  Bulk GTIN
# 0                0.0    6166.13
# 1                0.0    5808.29
# 2                0.0    8284.13
# 3                0.0    7961.90
# 4                0.0    7492.04

# %%
dropna_df.count()
# Out:
# Geography                    11800
# Timeframe                    11800
# Current Year Week Ending     11800
# Type                         11800
# ASP Current Year             11800
# Total Bulk and Bags Units    11800
# 4046 Units                   11800
# 4225 Units                   11800
# 4770 Units                   11800
# TotalBagged Units            11800
# SmlBagged Units              11800
# LrgBagged Units              11800
# X-LrgBagged Units            11800
# Bulk GTIN                    11800
# dtype: int64

# %%
dropcols_df = dropna_df.drop(columns = ['SmlBagged Units',
 'LrgBagged Units',
 'X-LrgBagged Units'])

dropcols_df.head()
# Out:
#   Geography Timeframe Current Year Week Ending          Type  \
# 0    Albany    Weekly      2020-01-06 00:00:00  Conventional
# 1    Albany    Weekly      2020-01-12 00:00:00  Conventional
# 2    Albany    Weekly      2020-01-19 00:00:00  Conventional
# 3    Albany    Weekly      2020-01-26 00:00:00  Conventional
# 4    Albany    Weekly      2020-02-02 00:00:00  Conventional
#
#    ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 0          1.155100                  161726.12     3737.00   140642.19
# 1          1.227609                  116738.30     3649.24    90717.11
# 2          1.088107                  138162.91     5057.86   108635.20
# 3          1.160866                  106202.76     4124.56    72571.73
# 4          1.251057                  186210.93     4933.07   156256.79
#
#    4770 Units  TotalBagged Units  Bulk GTIN
# 0      184.16           10996.65    6166.13
# 1      203.78           16359.88    5808.29
# 2      306.59           15879.12    8284.13
# 3      270.72           21273.86    7961.90
# 4      215.29           17313.74    7492.04

# %%
rearrange_cols_df = dropcols_df[['Geography',
 'Timeframe',
 'Current Year Week Ending',
 'Type',
 'ASP Current Year',
 '4046 Units',
 '4225 Units',
 '4770 Units',
 'Bulk GTIN',
 'TotalBagged Units',
 'Total Bulk and Bags Units']]

rearrange_cols_df.head()
# Out:
#   Geography Timeframe Current Year Week Ending          Type  \
# 0    Albany    Weekly      2020-01-06 00:00:00  Conventional
# 1    Albany    Weekly      2020-01-12 00:00:00  Conventional
# 2    Albany    Weekly      2020-01-19 00:00:00  Conventional
# 3    Albany    Weekly      2020-01-26 00:00:00  Conventional
# 4    Albany    Weekly      2020-02-02 00:00:00  Conventional
#
#    ASP Current Year  4046 Units  4225 Units  4770 Units  Bulk GTIN  \
# 0          1.155100     3737.00   140642.19      184.16    6166.13
# 1          1.227609     3649.24    90717.11      203.78    5808.29
# 2          1.088107     5057.86   108635.20      306.59    8284.13
# 3          1.160866     4124.56    72571.73      270.72    7961.90
# 4          1.251057     4933.07   156256.79      215.29    7492.04
#
#    TotalBagged Units  Total Bulk and Bags Units
# 0           10996.65                  161726.12
# 1           16359.88                  116738.30
# 2           15879.12                  138162.91
# 3           21273.86                  106202.76
# 4           17313.74                  186210.93

# %%
rearrange_cols_df.dtypes
# Out:
# Geography                     object
# Timeframe                     object
# Current Year Week Ending      object
# Type                          object
# ASP Current Year             float64
# 4046 Units                   float64
# 4225 Units                   float64
# 4770 Units                   float64
# Bulk GTIN                    float64
# TotalBagged Units            float64
# Total Bulk and Bags Units    float64
# dtype: object

# %%
rearrange_cols_df['Current Year Week Ending'] = pd.to_datetime(rearrange_cols_df['Current Year Week Ending'])

rearrange_cols_df.dtypes
# Out:
# Geography                            object
# Timeframe                            object
# Current Year Week Ending     datetime64[ns]
# Type                                 object
# ASP Current Year                    float64
# 4046 Units                          float64
# 4225 Units                          float64
# 4770 Units                          float64
# Bulk GTIN                           float64
# TotalBagged Units                   float64
# Total Bulk and Bags Units           float64
# dtype: object

# %% [markdown]
# # rearrange_cols_df.astype({'Current Year Week Ending' : datetime})

# %%
rearrange_cols_df['Current Year Week Ending'] = rearrange_cols_df['Current Year Week Ending'].dt.strftime("%Y-%m-%d")

rearrange_cols_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23888/899097227.py in <module>
# ----> 1 rearrange_cols_df['Current Year Week Ending'] = rearrange_cols_df['Current Year Week Ending'].dt.strftime("%Y-%m-%d")
#       2
#       3 rearrange_cols_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     504             return PeriodProperties(data, orig)
#     505
# --> 506         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
rearrange_cols_df.columns = ['City', 'Timeframe', 'Weekly Reporting Date', 'Produce Type', 'Average Avocado Price Year', 'Small/Medium (4046) Units', 'Large (4225) Units', 'Extra Large (4770) Units', 'Bulk GTIN', 'Bagged Units', 'Total Units'] 

rearrange_cols_df.head()
# Out:
#      City Timeframe Weekly Reporting Date  Produce Type  \
# 0  Albany    Weekly            2020-01-06  Conventional
# 1  Albany    Weekly            2020-01-12  Conventional
# 2  Albany    Weekly            2020-01-19  Conventional
# 3  Albany    Weekly            2020-01-26  Conventional
# 4  Albany    Weekly            2020-02-02  Conventional
#
#    Average Avocado Price Year  Small/Medium (4046) Units  Large (4225) Units  \
# 0                    1.155100                    3737.00           140642.19
# 1                    1.227609                    3649.24            90717.11
# 2                    1.088107                    5057.86           108635.20
# 3                    1.160866                    4124.56            72571.73
# 4                    1.251057                    4933.07           156256.79
#
#    Extra Large (4770) Units  Bulk GTIN  Bagged Units  Total Units
# 0                    184.16    6166.13      10996.65    161726.12
# 1                    203.78    5808.29      16359.88    116738.30
# 2                    306.59    8284.13      15879.12    138162.91
# 3                    270.72    7961.90      21273.86    106202.76
# 4                    215.29    7492.04      17313.74    186210.93

# %%
# rearrange_cols_df.sort_values(by="Weekly Reporting Date")

# rearrange_cols_df.head()

# %%
# rearrange_cols_df.sort_values(by=['Weekly Reporting Date', 'City'], inplace=True)

# rearrange_cols_df
