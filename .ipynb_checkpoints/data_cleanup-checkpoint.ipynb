# %%
# Import Dependencies
import pandas as pd
import os

# %%
import os, fnmatch
for root, dirs, files in os.walk("resources", topdown=False):
    resourcesVFiles = []
    resourcesRFiles = []
    resourcesTotFiles = []
    for name in files:
        if os.path.join(name).startswith("Volume"):
            resourcesVFiles.append(os.path.join(root, name))
        elif os.path.join(name).rfind("total"):
            resourcesTotFiles.append(os.path.join(root, name))
        else:
            resourcesRFiles.append(os.path.join(root, name))

# %%
numfile = len(resourcesVFiles)

# %%
for i in range(len(resourcesVFiles)):
    file = resourcesVFiles[i]
    i = i + 1
    variable_name = f"vol_{i}"
#     print(variable_name)
    globals()[variable_name] =  pd.read_csv(file)

# %%
if numfile == 3:
    volume_temp = pd.concat([vol_1, vol_2])
    volume = pd.concat([volume_temp, vol_3])
elif numfile == 2: 
    volume = pd.concat([vol_1, vol_2])
else:
    volume == vol_1

# %%
volume
# Out:
#             Week  Year      Status Total Volume California    Chile  \
# 0    Jan 5, 2020  2020      Actual   14,758,724     16,882   72,139
# 1   Jan 12, 2020  2020      Actual   29,622,992    145,088   80,639
# 2   Jan 19, 2020  2020      Actual   34,643,375    727,882  101,039
# 3   Jan 26, 2020  2020      Actual   30,230,597  1,280,256        0
# 4    Feb 2, 2020  2020      Actual   20,599,873  1,226,734        0
# ..           ...   ...         ...          ...        ...      ...
# 47   Dec 4, 2022  2022  Projection            0        NaN        0
# 48  Dec 11, 2022  2022  Projection            0        NaN        0
# 49  Dec 18, 2022  2022  Projection            0        NaN        0
# 50  Dec 25, 2022  2022  Projection            0        NaN        0
# 51   Jan 1, 2023  2022  Projection            0        NaN        0
#
#         Mexico Peru Colombia Dominican Republic
# 0   14,647,021    0   22,679                  0
# 1   29,397,263    0        0                  0
# 2   33,791,772    0   22,679                  0
# 3   28,927,660    0   22,679                  0
# 4   19,373,138    0        0                  0
# ..         ...  ...      ...                ...
# 47         NaN    0      NaN                NaN
# 48         NaN    0      NaN                NaN
# 49         NaN    0      NaN                NaN
# 50         NaN    0      NaN                NaN
# 51         NaN    0      NaN                NaN
#
# [157 rows x 10 columns]

# %%
volume.fillna(0)
# Out:
#             Week  Year      Status Total Volume California    Chile  \
# 0    Jan 5, 2020  2020      Actual   14,758,724     16,882   72,139
# 1   Jan 12, 2020  2020      Actual   29,622,992    145,088   80,639
# 2   Jan 19, 2020  2020      Actual   34,643,375    727,882  101,039
# 3   Jan 26, 2020  2020      Actual   30,230,597  1,280,256        0
# 4    Feb 2, 2020  2020      Actual   20,599,873  1,226,734        0
# ..           ...   ...         ...          ...        ...      ...
# 47   Dec 4, 2022  2022  Projection            0          0        0
# 48  Dec 11, 2022  2022  Projection            0          0        0
# 49  Dec 18, 2022  2022  Projection            0          0        0
# 50  Dec 25, 2022  2022  Projection            0          0        0
# 51   Jan 1, 2023  2022  Projection            0          0        0
#
#         Mexico Peru Colombia Dominican Republic
# 0   14,647,021    0   22,679                  0
# 1   29,397,263    0        0                  0
# 2   33,791,772    0   22,679                  0
# 3   28,927,660    0   22,679                  0
# 4   19,373,138    0        0                  0
# ..         ...  ...      ...                ...
# 47           0    0        0                  0
# 48           0    0        0                  0
# 49           0    0        0                  0
# 50           0    0        0                  0
# 51           0    0        0                  0
#
# [157 rows x 10 columns]

# %%
for col in volume.columns:
    if not (col == 'Week' or col == 'Status' or col == 'Year'):
        try:
            volume[col] = volume[col].str.replace(",", "").astype(float)
        except AttributeError:
            print(f'skipped {col}')
volume.dtypes
# Out:
# Week                   object
# Year                    int64
# Status                 object
# Total Volume          float64
# California            float64
# Chile                 float64
# Mexico                float64
# Peru                  float64
# Colombia              float64
# Dominican Republic    float64
# dtype: object

# %%
volume_transformed = volume.fillna(0)

# %%
volume_transformed
# Out:
#             Week  Year      Status  Total Volume  California     Chile  \
# 0    Jan 5, 2020  2020      Actual    14758724.0     16882.0   72139.0
# 1   Jan 12, 2020  2020      Actual    29622992.0    145088.0   80639.0
# 2   Jan 19, 2020  2020      Actual    34643375.0    727882.0  101039.0
# 3   Jan 26, 2020  2020      Actual    30230597.0   1280256.0       0.0
# 4    Feb 2, 2020  2020      Actual    20599873.0   1226734.0       0.0
# ..           ...   ...         ...           ...         ...       ...
# 47   Dec 4, 2022  2022  Projection           0.0         0.0       0.0
# 48  Dec 11, 2022  2022  Projection           0.0         0.0       0.0
# 49  Dec 18, 2022  2022  Projection           0.0         0.0       0.0
# 50  Dec 25, 2022  2022  Projection           0.0         0.0       0.0
# 51   Jan 1, 2023  2022  Projection           0.0         0.0       0.0
#
#         Mexico  Peru  Colombia  Dominican Republic
# 0   14647021.0   0.0   22679.0                 0.0
# 1   29397263.0   0.0       0.0                 0.0
# 2   33791772.0   0.0   22679.0                 0.0
# 3   28927660.0   0.0   22679.0                 0.0
# 4   19373138.0   0.0       0.0                 0.0
# ..         ...   ...       ...                 ...
# 47         0.0   0.0       0.0                 0.0
# 48         0.0   0.0       0.0                 0.0
# 49         0.0   0.0       0.0                 0.0
# 50         0.0   0.0       0.0                 0.0
# 51         0.0   0.0       0.0                 0.0
#
# [157 rows x 10 columns]

# %%
volume_transformed['WEDate'] = pd.to_datetime(volume_transformed.Week)

# %%
actual_vol_temp = volume_transformed.reset_index(drop='true')

# %%
actual_vol_temp.loc[(actual_vol_temp["Status"] == "Actual"), :]
# Out:
#              Week  Year  Status  Total Volume  California     Chile  \
# 0     Jan 5, 2020  2020  Actual    14758724.0     16882.0   72139.0
# 1    Jan 12, 2020  2020  Actual    29622992.0    145088.0   80639.0
# 2    Jan 19, 2020  2020  Actual    34643375.0    727882.0  101039.0
# 3    Jan 26, 2020  2020  Actual    30230597.0   1280256.0       0.0
# 4     Feb 2, 2020  2020  Actual    20599873.0   1226734.0       0.0
# ..            ...   ...     ...           ...         ...       ...
# 121   May 1, 2022  2022  Actual    26264324.0   6885495.0       0.0
# 122   May 8, 2022  2022  Actual    20669234.0   6512660.0       0.0
# 123  May 15, 2022  2022  Actual    19180237.0   5628260.0       0.0
# 124  May 22, 2022  2022  Actual    21117700.0   5477897.0       0.0
# 125  May 29, 2022  2022  Actual    22584157.0   6193663.0       0.0
#
#          Mexico       Peru  Colombia  Dominican Republic     WEDate
# 0    14647021.0        0.0   22679.0                 0.0 2020-01-05
# 1    29397263.0        0.0       0.0                 0.0 2020-01-12
# 2    33791772.0        0.0   22679.0                 0.0 2020-01-19
# 3    28927660.0        0.0   22679.0                 0.0 2020-01-26
# 4    19373138.0        0.0       0.0                 0.0 2020-02-02
# ..          ...        ...       ...                 ...        ...
# 121  19169455.0   100892.0  108479.0                 0.0 2022-05-01
# 122  13485959.0   214999.0  455615.0                 0.0 2022-05-08
# 123  12496727.0   838289.0  216959.0                 0.0 2022-05-15
# 124  13862334.0  1452028.0  325439.0                 0.0 2022-05-22
# 125  13390605.0  2686909.0  312978.0                 0.0 2022-05-29
#
# [126 rows x 11 columns]

# %%
import numpy as np
for i in np.arange(len(actual_vol_temp)):
    print(actual_vol_temp['Week'][i])
# Out:
# Jan 5, 2020
# Jan 12, 2020
# Jan 19, 2020
# Jan 26, 2020
# Feb 2, 2020
# Feb 9, 2020
# Feb 16, 2020
# Feb 23, 2020
# Mar 1, 2020
# Mar 8, 2020
# Mar 15, 2020
# Mar 22, 2020
# Mar 29, 2020
# Apr 5, 2020
# Apr 12, 2020
# Apr 19, 2020
# Apr 26, 2020
# May 3, 2020
# May 10, 2020
# May 17, 2020
# May 24, 2020
# May 31, 2020
# Jun 7, 2020
# Jun 14, 2020
# Jun 21, 2020
# Jun 28, 2020
# Jul 5, 2020
# Jul 12, 2020
# Jul 19, 2020
# Jul 26, 2020
# Aug 2, 2020
# Aug 9, 2020
# Aug 16, 2020
# Aug 23, 2020
# Aug 30, 2020
# Sep 6, 2020
# Sep 13, 2020
# Sep 20, 2020
# Sep 27, 2020
# Oct 4, 2020
# Oct 11, 2020
# Oct 18, 2020
# Oct 25, 2020
# Nov 1, 2020
# Nov 8, 2020
# Nov 15, 2020
# Nov 22, 2020
# Nov 29, 2020
# Dec 6, 2020
# Dec 13, 2020
# Dec 20, 2020
# Dec 27, 2020
# Jan 3, 2021
# Jan 10, 2021
# Jan 17, 2021
# Jan 24, 2021
# Jan 31, 2021
# Feb 7, 2021
# Feb 14, 2021
# Feb 21, 2021
# Feb 28, 2021
# Mar 7, 2021
# Mar 14, 2021
# Mar 21, 2021
# Mar 28, 2021
# Apr 4, 2021
# Apr 11, 2021
# Apr 18, 2021
# Apr 25, 2021
# May 2, 2021
# May 9, 2021
# May 16, 2021
# May 23, 2021
# May 30, 2021
# Jun 6, 2021
# Jun 13, 2021
# Jun 20, 2021
# Jun 27, 2021
# Jul 4, 2021
# Jul 11, 2021
# Jul 18, 2021
# Jul 25, 2021
# Aug 1, 2021
# Aug 8, 2021
# Aug 15, 2021
# Aug 22, 2021
# Aug 29, 2021
# Sep 5, 2021
# Sep 12, 2021
# Sep 19, 2021
# Sep 26, 2021
# Oct 3, 2021
# Oct 10, 2021
# Oct 17, 2021
# Oct 24, 2021
# Oct 31, 2021
# Nov 7, 2021
# Nov 14, 2021
# Nov 21, 2021
# Nov 28, 2021
# Dec 5, 2021
# Dec 12, 2021
# Dec 19, 2021
# Dec 26, 2021
# Jan 2, 2022
# Jan 9, 2022
# Jan 16, 2022
# Jan 23, 2022
# Jan 30, 2022
# Feb 6, 2022
# Feb 13, 2022
# Feb 20, 2022
# Feb 27, 2022
# Mar 6, 2022
# Mar 13, 2022
# Mar 20, 2022
# Mar 27, 2022
# Apr 3, 2022
# Apr 10, 2022
# Apr 17, 2022
# Apr 24, 2022
# May 1, 2022
# May 8, 2022
# May 15, 2022
# May 22, 2022
# May 29, 2022
# Jun 5, 2022
# Jun 12, 2022
# Jun 19, 2022
# Jun 26, 2022
# Jul 3, 2022
# Jul 10, 2022
# Jul 17, 2022
# Jul 24, 2022
# Jul 31, 2022
# Aug 7, 2022
# Aug 14, 2022
# Aug 21, 2022
# Aug 28, 2022
# Sep 4, 2022
# Sep 11, 2022
# Sep 18, 2022
# Sep 25, 2022
# Oct 2, 2022
# Oct 9, 2022
# Oct 16, 2022
# Oct 23, 2022
# Oct 30, 2022
# Nov 6, 2022
# Nov 13, 2022
# Nov 20, 2022
# Nov 27, 2022
# Dec 4, 2022
# Dec 11, 2022
# Dec 18, 2022
# Dec 25, 2022
# Jan 1, 2023

# %%
actual_vol_temp.to_dict("records")
# Out:
# [{'Week': 'Jan 5, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 14758724.0,
#   'California': 16882.0,
#   'Chile': 72139.0,
#   'Mexico': 14647021.0,
#   'Peru': 0.0,
#   'Colombia': 22679.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-01-05 00:00:00')},
#  {'Week': 'Jan 12, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 29622992.0,
#   'California': 145088.0,
#   'Chile': 80639.0,
#   'Mexico': 29397263.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-01-12 00:00:00')},
#  {'Week': 'Jan 19, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 34643375.0,
#   'California': 727882.0,
#   'Chile': 101039.0,
#   'Mexico': 33791772.0,
#   'Peru': 0.0,
#   'Colombia': 22679.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-01-19 00:00:00')},
#  {'Week': 'Jan 26, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 30230597.0,
#   'California': 1280256.0,
#   'Chile': 0.0,
#   'Mexico': 28927660.0,
#   'Peru': 0.0,
#   'Colombia': 22679.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-01-26 00:00:00')},
#  {'Week': 'Feb 2, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 20599873.0,
#   'California': 1226734.0,
#   'Chile': 0.0,
#   'Mexico': 19373138.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-02-02 00:00:00')},
#  {'Week': 'Feb 9, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 13370485.0,
#   'California': 1129128.0,
#   'Chile': 0.0,
#   'Mexico': 12241356.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-02-09 00:00:00')},
#  {'Week': 'Feb 16, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23003275.0,
#   'California': 2384605.0,
#   'Chile': 0.0,
#   'Mexico': 20618669.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-02-16 00:00:00')},
#  {'Week': 'Feb 23, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 27295113.0,
#   'California': 2927770.0,
#   'Chile': 0.0,
#   'Mexico': 24367342.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-02-23 00:00:00')},
#  {'Week': 'Mar 1, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 25489974.0,
#   'California': 4438598.0,
#   'Chile': 0.0,
#   'Mexico': 21051375.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-03-01 00:00:00')},
#  {'Week': 'Mar 8, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 21373018.0,
#   'California': 3742037.0,
#   'Chile': 0.0,
#   'Mexico': 17630980.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-03-08 00:00:00')},
#  {'Week': 'Mar 15, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 21790490.0,
#   'California': 1754931.0,
#   'Chile': 0.0,
#   'Mexico': 20012879.0,
#   'Peru': 22679.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-03-15 00:00:00')},
#  {'Week': 'Mar 22, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 24841247.0,
#   'California': 3667839.0,
#   'Chile': 0.0,
#   'Mexico': 21173408.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-03-22 00:00:00')},
#  {'Week': 'Mar 29, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 16431614.0,
#   'California': 3775546.0,
#   'Chile': 0.0,
#   'Mexico': 12656068.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-03-29 00:00:00')},
#  {'Week': 'Apr 5, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 11064408.0,
#   'California': 3598682.0,
#   'Chile': 0.0,
#   'Mexico': 7336702.0,
#   'Peru': 129022.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-04-05 00:00:00')},
#  {'Week': 'Apr 12, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 11314894.0,
#   'California': 1413008.0,
#   'Chile': 0.0,
#   'Mexico': 9837374.0,
#   'Peru': 64511.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-04-12 00:00:00')},
#  {'Week': 'Apr 19, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 29815403.0,
#   'California': 7140016.0,
#   'Chile': 0.0,
#   'Mexico': 22546364.0,
#   'Peru': 129022.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-04-19 00:00:00')},
#  {'Week': 'Apr 26, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 32142196.0,
#   'California': 7680479.0,
#   'Chile': 0.0,
#   'Mexico': 24397205.0,
#   'Peru': 64511.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-04-26 00:00:00')},
#  {'Week': 'May 3, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 26010697.0,
#   'California': 7916904.0,
#   'Chile': 0.0,
#   'Mexico': 17900259.0,
#   'Peru': 193533.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-05-03 00:00:00')},
#  {'Week': 'May 10, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 31213735.0,
#   'California': 7871218.0,
#   'Chile': 0.0,
#   'Mexico': 22955448.0,
#   'Peru': 387067.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-05-10 00:00:00')},
#  {'Week': 'May 17, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 24820709.0,
#   'California': 6675017.0,
#   'Chile': 0.0,
#   'Mexico': 17565090.0,
#   'Peru': 580601.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-05-17 00:00:00')},
#  {'Week': 'May 24, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23555958.0,
#   'California': 7536867.0,
#   'Chile': 0.0,
#   'Mexico': 15137435.0,
#   'Peru': 881654.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-05-24 00:00:00')},
#  {'Week': 'May 31, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23435943.0,
#   'California': 5380056.0,
#   'Chile': 0.0,
#   'Mexico': 16163555.0,
#   'Peru': 1892331.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-05-31 00:00:00')},
#  {'Week': 'Jun 7, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 24640121.0,
#   'California': 5555358.0,
#   'Chile': 0.0,
#   'Mexico': 15402500.0,
#   'Peru': 3638870.0,
#   'Colombia': 43391.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-06-07 00:00:00')},
#  {'Week': 'Jun 14, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 29204843.0,
#   'California': 6052939.0,
#   'Chile': 0.0,
#   'Mexico': 17882712.0,
#   'Peru': 5182406.0,
#   'Colombia': 86783.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-06-14 00:00:00')},
#  {'Week': 'Jun 21, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 29766704.0,
#   'California': 6239079.0,
#   'Chile': 0.0,
#   'Mexico': 17937685.0,
#   'Peru': 5504963.0,
#   'Colombia': 84975.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-06-21 00:00:00')},
#  {'Week': 'Jun 28, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 30475084.0,
#   'California': 6907566.0,
#   'Chile': 0.0,
#   'Mexico': 15891967.0,
#   'Peru': 7569324.0,
#   'Colombia': 106225.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-06-28 00:00:00')},
#  {'Week': 'Jul 5, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 25046120.0,
#   'California': 5343331.0,
#   'Chile': 0.0,
#   'Mexico': 12073018.0,
#   'Peru': 7545239.0,
#   'Colombia': 84529.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-07-05 00:00:00')},
#  {'Week': 'Jul 12, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23704208.0,
#   'California': 5166964.0,
#   'Chile': 0.0,
#   'Mexico': 11463798.0,
#   'Peru': 6967218.0,
#   'Colombia': 106225.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-07-12 00:00:00')},
#  {'Week': 'Jul 19, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 25187185.0,
#   'California': 4594958.0,
#   'Chile': 0.0,
#   'Mexico': 13237170.0,
#   'Peru': 7268271.0,
#   'Colombia': 86783.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-07-19 00:00:00')},
#  {'Week': 'Jul 26, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 27011258.0,
#   'California': 4301752.0,
#   'Chile': 0.0,
#   'Mexico': 16687816.0,
#   'Peru': 5893320.0,
#   'Colombia': 128368.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-07-26 00:00:00')},
#  {'Week': 'Aug 2, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 27936294.0,
#   'California': 4218923.0,
#   'Chile': 0.0,
#   'Mexico': 17448968.0,
#   'Peru': 6116530.0,
#   'Colombia': 151871.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-08-02 00:00:00')},
#  {'Week': 'Aug 9, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23734849.0,
#   'California': 4333200.0,
#   'Chile': 0.0,
#   'Mexico': 14564533.0,
#   'Peru': 4773835.0,
#   'Colombia': 63279.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-08-09 00:00:00')},
#  {'Week': 'Aug 16, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 20562991.0,
#   'California': 3943294.0,
#   'Chile': 0.0,
#   'Mexico': 12812569.0,
#   'Peru': 3698647.0,
#   'Colombia': 108479.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-08-16 00:00:00')},
#  {'Week': 'Aug 23, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 24574210.0,
#   'California': 3571556.0,
#   'Chile': 0.0,
#   'Mexico': 17841215.0,
#   'Peru': 3118045.0,
#   'Colombia': 43391.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-08-23 00:00:00')},
#  {'Week': 'Aug 30, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 22098016.0,
#   'California': 3853037.0,
#   'Chile': 0.0,
#   'Mexico': 15713819.0,
#   'Peru': 2472932.0,
#   'Colombia': 58226.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-08-30 00:00:00')},
#  {'Week': 'Sep 6, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23901341.0,
#   'California': 3834426.0,
#   'Chile': 0.0,
#   'Mexico': 18110072.0,
#   'Peru': 1956842.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-09-06 00:00:00')},
#  {'Week': 'Sep 13, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 22808594.0,
#   'California': 2696919.0,
#   'Chile': 23039.0,
#   'Mexico': 19013446.0,
#   'Peru': 1075188.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-09-13 00:00:00')},
#  {'Week': 'Sep 20, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 20859020.0,
#   'California': 3074999.0,
#   'Chile': 90239.0,
#   'Mexico': 17349720.0,
#   'Peru': 344060.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-09-20 00:00:00')},
#  {'Week': 'Sep 27, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 25411229.0,
#   'California': 2696299.0,
#   'Chile': 250048.0,
#   'Mexico': 22421873.0,
#   'Peru': 43007.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-09-27 00:00:00')},
#  {'Week': 'Oct 4, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23682194.0,
#   'California': 1798475.0,
#   'Chile': 207250.0,
#   'Mexico': 21676467.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-10-04 00:00:00')},
#  {'Week': 'Oct 11, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 25825140.0,
#   'California': 1094090.0,
#   'Chile': 183923.0,
#   'Mexico': 24547125.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-10-11 00:00:00')},
#  {'Week': 'Oct 18, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 25265160.0,
#   'California': 999614.0,
#   'Chile': 116039.0,
#   'Mexico': 23998527.0,
#   'Peru': 0.0,
#   'Colombia': 150978.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-10-18 00:00:00')},
#  {'Week': 'Oct 25, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 25112584.0,
#   'California': 895680.0,
#   'Chile': 59519.0,
#   'Mexico': 24006404.0,
#   'Peru': 0.0,
#   'Colombia': 150978.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-10-25 00:00:00')},
#  {'Week': 'Nov 1, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 22490557.0,
#   'California': 596262.0,
#   'Chile': 0.0,
#   'Mexico': 21872530.0,
#   'Peru': 0.0,
#   'Colombia': 21763.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-11-01 00:00:00')},
#  {'Week': 'Nov 8, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 19471123.0,
#   'California': 741608.0,
#   'Chile': 0.0,
#   'Mexico': 18664426.0,
#   'Peru': 0.0,
#   'Colombia': 65087.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-11-08 00:00:00')},
#  {'Week': 'Nov 15, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 25850459.0,
#   'California': 630569.0,
#   'Chile': 0.0,
#   'Mexico': 25219889.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-11-15 00:00:00')},
#  {'Week': 'Nov 22, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23443687.0,
#   'California': 562002.0,
#   'Chile': 0.0,
#   'Mexico': 22881684.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-11-22 00:00:00')},
#  {'Week': 'Nov 29, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 23397741.0,
#   'California': 541561.0,
#   'Chile': 0.0,
#   'Mexico': 22856178.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-11-29 00:00:00')},
#  {'Week': 'Dec 6, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 21936864.0,
#   'California': 453582.0,
#   'Chile': 0.0,
#   'Mexico': 21483280.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-12-06 00:00:00')},
#  {'Week': 'Dec 13, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 21052538.0,
#   'California': 55383.0,
#   'Chile': 0.0,
#   'Mexico': 20924579.0,
#   'Peru': 0.0,
#   'Colombia': 72574.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-12-13 00:00:00')},
#  {'Week': 'Dec 20, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 24158163.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 24158162.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-12-20 00:00:00')},
#  {'Week': 'Dec 27, 2020',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 20190717.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 20190717.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2020-12-27 00:00:00')},
#  {'Week': 'Jan 3, 2021',
#   'Year': 2020,
#   'Status': 'Actual',
#   'Total Volume': 20344847.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 20344846.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-01-03 00:00:00')},
#  {'Week': 'Jan 10, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 29700864.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 29655504.0,
#   'Peru': 0.0,
#   'Colombia': 45359.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-01-10 00:00:00')},
#  {'Week': 'Jan 17, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 35559789.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 35491750.0,
#   'Peru': 0.0,
#   'Colombia': 68038.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-01-17 00:00:00')},
#  {'Week': 'Jan 24, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 33510617.0,
#   'California': 179683.0,
#   'Chile': 0.0,
#   'Mexico': 33308253.0,
#   'Peru': 0.0,
#   'Colombia': 22679.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-01-24 00:00:00')},
#  {'Week': 'Jan 31, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 27577208.0,
#   'California': 106086.0,
#   'Chile': 0.0,
#   'Mexico': 27471122.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-01-31 00:00:00')},
#  {'Week': 'Feb 7, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 19581434.0,
#   'California': 101282.0,
#   'Chile': 0.0,
#   'Mexico': 19480151.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-02-07 00:00:00')},
#  {'Week': 'Feb 14, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 24677365.0,
#   'California': 236985.0,
#   'Chile': 0.0,
#   'Mexico': 24440378.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-02-14 00:00:00')},
#  {'Week': 'Feb 21, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 26652888.0,
#   'California': 669481.0,
#   'Chile': 0.0,
#   'Mexico': 25965263.0,
#   'Peru': 0.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-02-21 00:00:00')},
#  {'Week': 'Feb 28, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 28001304.0,
#   'California': 1557587.0,
#   'Chile': 0.0,
#   'Mexico': 26425573.0,
#   'Peru': 0.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-02-28 00:00:00')},
#  {'Week': 'Mar 7, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 26205180.0,
#   'California': 1661053.0,
#   'Chile': 0.0,
#   'Mexico': 24525982.0,
#   'Peru': 0.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-03-07 00:00:00')},
#  {'Week': 'Mar 14, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 27672460.0,
#   'California': 1224875.0,
#   'Chile': 0.0,
#   'Mexico': 26429440.0,
#   'Peru': 0.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-03-14 00:00:00')},
#  {'Week': 'Mar 21, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 26953337.0,
#   'California': 2191075.0,
#   'Chile': 0.0,
#   'Mexico': 24762261.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-03-21 00:00:00')},
#  {'Week': 'Mar 28, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 29240846.0,
#   'California': 3531148.0,
#   'Chile': 0.0,
#   'Mexico': 25709697.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-03-28 00:00:00')},
#  {'Week': 'Apr 4, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 17378989.0,
#   'California': 4131836.0,
#   'Chile': 0.0,
#   'Mexico': 13247152.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-04-04 00:00:00')},
#  {'Week': 'Apr 11, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 25481894.0,
#   'California': 4537148.0,
#   'Chile': 0.0,
#   'Mexico': 20905098.0,
#   'Peru': 21503.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-04-11 00:00:00')},
#  {'Week': 'Apr 18, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 31701076.0,
#   'California': 5728289.0,
#   'Chile': 0.0,
#   'Mexico': 25864460.0,
#   'Peru': 108325.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-04-18 00:00:00')},
#  {'Week': 'Apr 25, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 28806344.0,
#   'California': 5476932.0,
#   'Chile': 0.0,
#   'Mexico': 23242589.0,
#   'Peru': 86822.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-04-25 00:00:00')},
#  {'Week': 'May 2, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 24891096.0,
#   'California': 5243447.0,
#   'Chile': 0.0,
#   'Mexico': 19607732.0,
#   'Peru': 21772.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-05-02 00:00:00')},
#  {'Week': 'May 9, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 25269627.0,
#   'California': 5271833.0,
#   'Chile': 0.0,
#   'Mexico': 19719569.0,
#   'Peru': 260081.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-05-09 00:00:00')},
#  {'Week': 'May 16, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 26773147.0,
#   'California': 5300421.0,
#   'Chile': 0.0,
#   'Mexico': 21281475.0,
#   'Peru': 173106.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-05-16 00:00:00')},
#  {'Week': 'May 23, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 29815313.0,
#   'California': 5234757.0,
#   'Chile': 0.0,
#   'Mexico': 23549038.0,
#   'Peru': 1031516.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-05-23 00:00:00')},
#  {'Week': 'May 30, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 22089115.0,
#   'California': 5611118.0,
#   'Chile': 0.0,
#   'Mexico': 14223235.0,
#   'Peru': 2213937.0,
#   'Colombia': 40823.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-05-30 00:00:00')},
#  {'Week': 'Jun 6, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 20959105.0,
#   'California': 3747198.0,
#   'Chile': 0.0,
#   'Mexico': 14855079.0,
#   'Peru': 2356826.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-06-06 00:00:00')},
#  {'Week': 'Jun 13, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 32965708.0,
#   'California': 5144610.0,
#   'Chile': 0.0,
#   'Mexico': 23000729.0,
#   'Peru': 4779544.0,
#   'Colombia': 40823.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-06-13 00:00:00')},
#  {'Week': 'Jun 20, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 27404443.0,
#   'California': 4342754.0,
#   'Chile': 0.0,
#   'Mexico': 19654799.0,
#   'Peru': 3388745.0,
#   'Colombia': 18143.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-06-20 00:00:00')},
#  {'Week': 'Jun 27, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 27647151.0,
#   'California': 3977735.0,
#   'Chile': 0.0,
#   'Mexico': 16422211.0,
#   'Peru': 7074839.0,
#   'Colombia': 172364.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-06-27 00:00:00')},
#  {'Week': 'Jul 4, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 25862424.0,
#   'California': 3816774.0,
#   'Chile': 0.0,
#   'Mexico': 16028356.0,
#   'Peru': 5931109.0,
#   'Colombia': 86182.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-07-04 00:00:00')},
#  {'Week': 'Jul 11, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 25751949.0,
#   'California': 2976775.0,
#   'Chile': 0.0,
#   'Mexico': 15863383.0,
#   'Peru': 6784784.0,
#   'Colombia': 127005.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-07-11 00:00:00')},
#  {'Week': 'Jul 18, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 26187611.0,
#   'California': 4344062.0,
#   'Chile': 0.0,
#   'Mexico': 15594177.0,
#   'Peru': 6077006.0,
#   'Colombia': 172364.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-07-18 00:00:00')},
#  {'Week': 'Jul 25, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 28527520.0,
#   'California': 4873308.0,
#   'Chile': 0.0,
#   'Mexico': 17203295.0,
#   'Peru': 6251335.0,
#   'Colombia': 199580.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-07-25 00:00:00')},
#  {'Week': 'Aug 1, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 24700254.0,
#   'California': 4609129.0,
#   'Chile': 0.0,
#   'Mexico': 14194670.0,
#   'Peru': 5760376.0,
#   'Colombia': 136077.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-08-01 00:00:00')},
#  {'Week': 'Aug 8, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 20178861.0,
#   'California': 4031443.0,
#   'Chile': 0.0,
#   'Mexico': 10015046.0,
#   'Peru': 5891967.0,
#   'Colombia': 240403.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-08-08 00:00:00')},
#  {'Week': 'Aug 15, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 23216397.0,
#   'California': 3339592.0,
#   'Chile': 0.0,
#   'Mexico': 14534890.0,
#   'Peru': 5321048.0,
#   'Colombia': 20865.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-08-15 00:00:00')},
#  {'Week': 'Aug 22, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 23215758.0,
#   'California': 3118906.0,
#   'Chile': 0.0,
#   'Mexico': 15110938.0,
#   'Peru': 4854371.0,
#   'Colombia': 131541.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-08-22 00:00:00')},
#  {'Week': 'Aug 29, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 21436330.0,
#   'California': 2896101.0,
#   'Chile': 0.0,
#   'Mexico': 14357553.0,
#   'Peru': 4046597.0,
#   'Colombia': 136077.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-08-29 00:00:00')},
#  {'Week': 'Sep 5, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 18253185.0,
#   'California': 2189759.0,
#   'Chile': 0.0,
#   'Mexico': 12841738.0,
#   'Peru': 3153648.0,
#   'Colombia': 68038.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-09-05 00:00:00')},
#  {'Week': 'Sep 12, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 19256634.0,
#   'California': 1122573.0,
#   'Chile': 0.0,
#   'Mexico': 15241594.0,
#   'Peru': 2720101.0,
#   'Colombia': 172364.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-09-12 00:00:00')},
#  {'Week': 'Sep 19, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 21600396.0,
#   'California': 937432.0,
#   'Chile': 0.0,
#   'Mexico': 17047812.0,
#   'Peru': 3470001.0,
#   'Colombia': 145149.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-09-19 00:00:00')},
#  {'Week': 'Sep 26, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 28675248.0,
#   'California': 618357.0,
#   'Chile': 20411.0,
#   'Mexico': 25447808.0,
#   'Peru': 2502488.0,
#   'Colombia': 86182.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-09-26 00:00:00')},
#  {'Week': 'Oct 3, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 22413092.0,
#   'California': 34104.0,
#   'Chile': 22679.0,
#   'Mexico': 20975354.0,
#   'Peru': 1312914.0,
#   'Colombia': 68038.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-10-03 00:00:00')},
#  {'Week': 'Oct 10, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 17285786.0,
#   'California': 0.0,
#   'Chile': 254011.0,
#   'Mexico': 16466436.0,
#   'Peru': 501835.0,
#   'Colombia': 63502.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-10-10 00:00:00')},
#  {'Week': 'Oct 17, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 21472414.0,
#   'California': 0.0,
#   'Chile': 276691.0,
#   'Mexico': 21195723.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-10-17 00:00:00')},
#  {'Week': 'Oct 24, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 26594963.0,
#   'California': 0.0,
#   'Chile': 131541.0,
#   'Mexico': 26463421.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-10-24 00:00:00')},
#  {'Week': 'Oct 31, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 20861959.0,
#   'California': 0.0,
#   'Chile': 852752.0,
#   'Mexico': 20009205.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-10-31 00:00:00')},
#  {'Week': 'Nov 7, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 22975783.0,
#   'California': 0.0,
#   'Chile': 526166.0,
#   'Mexico': 22449616.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-11-07 00:00:00')},
#  {'Week': 'Nov 14, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 26288840.0,
#   'California': 0.0,
#   'Chile': 136077.0,
#   'Mexico': 26152762.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-11-14 00:00:00')},
#  {'Week': 'Nov 21, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 20613611.0,
#   'California': 2968.0,
#   'Chile': 539774.0,
#   'Mexico': 20070867.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-11-21 00:00:00')},
#  {'Week': 'Nov 28, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 18688582.0,
#   'California': 0.0,
#   'Chile': 68038.0,
#   'Mexico': 18620543.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-11-28 00:00:00')},
#  {'Week': 'Dec 5, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 20439672.0,
#   'California': 0.0,
#   'Chile': 566990.0,
#   'Mexico': 19827322.0,
#   'Peru': 0.0,
#   'Colombia': 45359.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-12-05 00:00:00')},
#  {'Week': 'Dec 12, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 21471967.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 21249707.0,
#   'Peru': 0.0,
#   'Colombia': 222260.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-12-12 00:00:00')},
#  {'Week': 'Dec 19, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 23405281.0,
#   'California': 0.0,
#   'Chile': 489879.0,
#   'Mexico': 22783860.0,
#   'Peru': 0.0,
#   'Colombia': 131541.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-12-19 00:00:00')},
#  {'Week': 'Dec 26, 2021',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 19741436.0,
#   'California': 2086.0,
#   'Chile': 0.0,
#   'Mexico': 19698526.0,
#   'Peru': 0.0,
#   'Colombia': 40823.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2021-12-26 00:00:00')},
#  {'Week': 'Jan 2, 2022',
#   'Year': 2021,
#   'Status': 'Actual',
#   'Total Volume': 20352158.0,
#   'California': 0.0,
#   'Chile': 63502.0,
#   'Mexico': 19971140.0,
#   'Peru': 0.0,
#   'Colombia': 154221.0,
#   'Dominican Republic': 163293.0,
#   'WEDate': Timestamp('2022-01-02 00:00:00')},
#  {'Week': 'Jan 9, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 25245161.0,
#   'California': 42476.0,
#   'Chile': 0.0,
#   'Mexico': 24826202.0,
#   'Peru': 0.0,
#   'Colombia': 154221.0,
#   'Dominican Republic': 222260.0,
#   'WEDate': Timestamp('2022-01-09 00:00:00')},
#  {'Week': 'Jan 16, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 25803376.0,
#   'California': 254741.0,
#   'Chile': 45359.0,
#   'Mexico': 25417092.0,
#   'Peru': 0.0,
#   'Colombia': 45359.0,
#   'Dominican Republic': 40823.0,
#   'WEDate': Timestamp('2022-01-16 00:00:00')},
#  {'Week': 'Jan 23, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 27651102.0,
#   'California': 1358681.0,
#   'Chile': 0.0,
#   'Mexico': 26249028.0,
#   'Peru': 0.0,
#   'Colombia': 43391.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-01-23 00:00:00')},
#  {'Week': 'Jan 30, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 27067867.0,
#   'California': 2351814.0,
#   'Chile': 199580.0,
#   'Mexico': 24429687.0,
#   'Peru': 0.0,
#   'Colombia': 86783.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-01-30 00:00:00')},
#  {'Week': 'Feb 6, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 23700493.0,
#   'California': 2529702.0,
#   'Chile': 226796.0,
#   'Mexico': 20705339.0,
#   'Peru': 0.0,
#   'Colombia': 238655.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-02-06 00:00:00')},
#  {'Week': 'Feb 13, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 13538106.0,
#   'California': 1837830.0,
#   'Chile': 199580.0,
#   'Mexico': 10979992.0,
#   'Peru': 0.0,
#   'Colombia': 520702.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-02-13 00:00:00')},
#  {'Week': 'Feb 20, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 11411144.0,
#   'California': 3432575.0,
#   'Chile': 222260.0,
#   'Mexico': 7300693.0,
#   'Peru': 0.0,
#   'Colombia': 455615.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-02-20 00:00:00')},
#  {'Week': 'Feb 27, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 26431640.0,
#   'California': 3658560.0,
#   'Chile': 594205.0,
#   'Mexico': 21853434.0,
#   'Peru': 0.0,
#   'Colombia': 325439.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-02-27 00:00:00')},
#  {'Week': 'Mar 6, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 29166929.0,
#   'California': 3454216.0,
#   'Chile': 576061.0,
#   'Mexico': 24811211.0,
#   'Peru': 0.0,
#   'Colombia': 325439.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-03-06 00:00:00')},
#  {'Week': 'Mar 13, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 25843478.0,
#   'California': 3630077.0,
#   'Chile': 426376.0,
#   'Mexico': 21678544.0,
#   'Peru': 0.0,
#   'Colombia': 108479.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-03-13 00:00:00')},
#  {'Week': 'Mar 20, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 22051255.0,
#   'California': 3436635.0,
#   'Chile': 145149.0,
#   'Mexico': 18035551.0,
#   'Peru': 0.0,
#   'Colombia': 433919.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-03-20 00:00:00')},
#  {'Week': 'Mar 27, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 18189130.0,
#   'California': 3153811.0,
#   'Chile': 299370.0,
#   'Mexico': 14519564.0,
#   'Peru': 64511.0,
#   'Colombia': 151871.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-03-27 00:00:00')},
#  {'Week': 'Apr 3, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 21009354.0,
#   'California': 2482199.0,
#   'Chile': 340194.0,
#   'Mexico': 18021432.0,
#   'Peru': 100440.0,
#   'Colombia': 65087.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-04-03 00:00:00')},
#  {'Week': 'Apr 10, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 23623647.0,
#   'California': 3972180.0,
#   'Chile': 81646.0,
#   'Mexico': 19288540.0,
#   'Peru': 86015.0,
#   'Colombia': 195263.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-04-10 00:00:00')},
#  {'Week': 'Apr 17, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 15061578.0,
#   'California': 5023348.0,
#   'Chile': 40823.0,
#   'Mexico': 9827999.0,
#   'Peru': 60927.0,
#   'Colombia': 108479.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-04-17 00:00:00')},
#  {'Week': 'Apr 24, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 28441114.0,
#   'California': 6160887.0,
#   'Chile': 45359.0,
#   'Mexico': 22040948.0,
#   'Peru': 150526.0,
#   'Colombia': 43391.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-04-24 00:00:00')},
#  {'Week': 'May 1, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 26264324.0,
#   'California': 6885495.0,
#   'Chile': 0.0,
#   'Mexico': 19169455.0,
#   'Peru': 100892.0,
#   'Colombia': 108479.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-05-01 00:00:00')},
#  {'Week': 'May 8, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 20669234.0,
#   'California': 6512660.0,
#   'Chile': 0.0,
#   'Mexico': 13485959.0,
#   'Peru': 214999.0,
#   'Colombia': 455615.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-05-08 00:00:00')},
#  {'Week': 'May 15, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 19180237.0,
#   'California': 5628260.0,
#   'Chile': 0.0,
#   'Mexico': 12496727.0,
#   'Peru': 838289.0,
#   'Colombia': 216959.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-05-15 00:00:00')},
#  {'Week': 'May 22, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 21117700.0,
#   'California': 5477897.0,
#   'Chile': 0.0,
#   'Mexico': 13862334.0,
#   'Peru': 1452028.0,
#   'Colombia': 325439.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-05-22 00:00:00')},
#  {'Week': 'May 29, 2022',
#   'Year': 2022,
#   'Status': 'Actual',
#   'Total Volume': 22584157.0,
#   'California': 6193663.0,
#   'Chile': 0.0,
#   'Mexico': 13390605.0,
#   'Peru': 2686909.0,
#   'Colombia': 312978.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-05-29 00:00:00')},
#  {'Week': 'Jun 5, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 22644009.0,
#   'California': 5262846.0,
#   'Chile': 0.0,
#   'Mexico': 13051991.0,
#   'Peru': 3884404.0,
#   'Colombia': 444767.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-06-05 00:00:00')},
#  {'Week': 'Jun 12, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 23058421.0,
#   'California': 5104225.0,
#   'Chile': 0.0,
#   'Mexico': 13472991.0,
#   'Peru': 4036436.0,
#   'Colombia': 444767.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-06-12 00:00:00')},
#  {'Week': 'Jun 19, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 24789009.0,
#   'California': 4954902.0,
#   'Chile': 0.0,
#   'Mexico': 13919991.0,
#   'Peru': 5447652.0,
#   'Colombia': 466463.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-06-19 00:00:00')},
#  {'Week': 'Jun 26, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 25129042.0,
#   'California': 5202927.0,
#   'Chile': 0.0,
#   'Mexico': 13484991.0,
#   'Peru': 5996356.0,
#   'Colombia': 444767.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-06-26 00:00:00')},
#  {'Week': 'Jul 3, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 25549588.0,
#   'California': 4070534.0,
#   'Chile': 0.0,
#   'Mexico': 12971991.0,
#   'Peru': 8062294.0,
#   'Colombia': 444767.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-07-03 00:00:00')},
#  {'Week': 'Jul 10, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 25425587.0,
#   'California': 3754834.0,
#   'Chile': 0.0,
#   'Mexico': 12665639.0,
#   'Peru': 8603737.0,
#   'Colombia': 401375.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-07-10 00:00:00')},
#  {'Week': 'Jul 17, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 27061224.0,
#   'California': 4007077.0,
#   'Chile': 0.0,
#   'Mexico': 13664313.0,
#   'Peru': 8966761.0,
#   'Colombia': 423071.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-07-17 00:00:00')},
#  {'Week': 'Jul 24, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 27876810.0,
#   'California': 3864830.0,
#   'Chile': 0.0,
#   'Mexico': 14320991.0,
#   'Peru': 9354701.0,
#   'Colombia': 336287.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-07-24 00:00:00')},
#  {'Week': 'Jul 31, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 26152564.0,
#   'California': 3543279.0,
#   'Chile': 0.0,
#   'Mexico': 13359988.0,
#   'Peru': 8891312.0,
#   'Colombia': 357983.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-07-31 00:00:00')},
#  {'Week': 'Aug 7, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 25232068.0,
#   'California': 2814220.0,
#   'Chile': 0.0,
#   'Mexico': 13628527.0,
#   'Peru': 8409640.0,
#   'Colombia': 379679.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-08-07 00:00:00')},
#  {'Week': 'Aug 14, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 26731684.0,
#   'California': 2871010.0,
#   'Chile': 0.0,
#   'Mexico': 15784453.0,
#   'Peru': 8076220.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-08-14 00:00:00')},
#  {'Week': 'Aug 21, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 24894737.0,
#   'California': 2831094.0,
#   'Chile': 0.0,
#   'Mexico': 15305537.0,
#   'Peru': 6758104.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-08-21 00:00:00')},
#  {'Week': 'Aug 28, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 22902539.0,
#   'California': 2729217.0,
#   'Chile': 0.0,
#   'Mexico': 14812854.0,
#   'Peru': 5360467.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-08-28 00:00:00')},
#  {'Week': 'Sep 4, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 18505863.0,
#   'California': 856653.0,
#   'Chile': 0.0,
#   'Mexico': 13191759.0,
#   'Peru': 4457449.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-09-04 00:00:00')},
#  {'Week': 'Sep 11, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 21412331.0,
#   'California': 653716.0,
#   'Chile': 0.0,
#   'Mexico': 17038342.0,
#   'Peru': 3720272.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-09-11 00:00:00')},
#  {'Week': 'Sep 18, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 19405226.0,
#   'California': 430957.0,
#   'Chile': 0.0,
#   'Mexico': 15735688.0,
#   'Peru': 3238579.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-09-18 00:00:00')},
#  {'Week': 'Sep 25, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 22027183.0,
#   'California': 416125.0,
#   'Chile': 0.0,
#   'Mexico': 19299403.0,
#   'Peru': 2311654.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-09-25 00:00:00')},
#  {'Week': 'Oct 2, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 21085104.0,
#   'California': 332437.0,
#   'Chile': 0.0,
#   'Mexico': 19418511.0,
#   'Peru': 1334155.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-10-02 00:00:00')},
#  {'Week': 'Oct 9, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 20288232.0,
#   'California': 112626.0,
#   'Chile': 0.0,
#   'Mexico': 20067817.0,
#   'Peru': 107787.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-10-09 00:00:00')},
#  {'Week': 'Oct 16, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-10-16 00:00:00')},
#  {'Week': 'Oct 23, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-10-23 00:00:00')},
#  {'Week': 'Oct 30, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-10-30 00:00:00')},
#  {'Week': 'Nov 6, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-11-06 00:00:00')},
#  {'Week': 'Nov 13, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-11-13 00:00:00')},
#  {'Week': 'Nov 20, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-11-20 00:00:00')},
#  {'Week': 'Nov 27, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-11-27 00:00:00')},
#  {'Week': 'Dec 4, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-12-04 00:00:00')},
#  {'Week': 'Dec 11, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-12-11 00:00:00')},
#  {'Week': 'Dec 18, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-12-18 00:00:00')},
#  {'Week': 'Dec 25, 2022',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2022-12-25 00:00:00')},
#  {'Week': 'Jan 1, 2023',
#   'Year': 2022,
#   'Status': 'Projection',
#   'Total Volume': 0.0,
#   'California': 0.0,
#   'Chile': 0.0,
#   'Mexico': 0.0,
#   'Peru': 0.0,
#   'Colombia': 0.0,
#   'Dominican Republic': 0.0,
#   'WEDate': Timestamp('2023-01-01 00:00:00')}]
